# %%
ls
# Out:
# Untitled.ipynb         cc.py                  findhomography.py
# camcalib_1115.py       featurematcher.py      left01.jpg
# camera_calibration.py  featurematcher2.py     left02.jpg

# %%
# %run camera_calibration.py
# Out:
# Total error:  0.0065110495826708635
